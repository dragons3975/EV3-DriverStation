# %% [markdown]
# <p style="text-align: center; font-size: 35px;">Initiation a Python</p>
#
# <style>
# div.info {
#     background-color: #A7D2E3;
#
#     border-left: 5px solid #176BC7;
#     padding: 0.5em;
#     }
#  </style>

# %% [markdown]
# La programmation c'est expliquer comment résoudre un problème à un esclave très obéissant, très fort en calcul mental, mais qui ne se pose aucune question (l'ordinateur). Il faut donc expliquer chaque étape de manière très précise.
#
# Contrairement à un interlocuteur humain qui peut s'adapter et comprendre une phrase approximative et mal formulé, donner des ordres à un ordinateur nécessite de s'adapter à sa langue et à sa logique.
#
# C'est cette langue et cette logique que tu va découvrir dans cette formation.

# %% [markdown]
# # Expression Arithmétiques
#
# <style>
# div.info {
#     background-color: #FF8D3A;
#     color: white;
#     border-left: 5px solid #DE630A;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Une grande partie du code du robot a pour but de <b>calculer et manipuler des valeurs numériques</b>: la valeur d'un capteur, la consigne d'un moteur, le temps écoulé depuis le début du match...
#
# C'est la première chose que tu vas appprendre à programmer.
# </div>

# %% [markdown]
# ## Calcul simples
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
# Python (comme la majorité des langages de programmation) contient tout les opérateurs arithmétiques pour faire des calculs simples:
# <ul>
#     <li> Addition: <b>+</b> </li>
#     <li> Soustraction: <b>-</b> </li>
#     <li> Multiplication: <b>*</b> </li>
#     <li> Division: <b>/</b> </li>
#  </ul>
#
# La priorité des opérations est la même qu'en mathématique. On peut utiliser des parenthèses pour changer l'ordre des opérations.
#
# </div>
#
# Demande à Python de faire les calculs suivants:

# %%
import math

# %% [markdown]
# $3 + 7$

# %%
3 + 7
# Out:
# 10

# %% [markdown]
# $ 4 \times (2 + 1)$

# %%
4 * (2 + 1)
# Out:
# 12

# %% [markdown]
# $ 1 - \dfrac{3}{4} $

# %%
1 - 3 / 4
# Out:
# 0.25

# %% [markdown]
# $ 2\times4 - \dfrac{64}{2} $

# %%
2 * 4 - 64 / 2
# Out:
# -24.0

# %% [markdown]
# ## Calcul booléen
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
# Il contient aussi de quoi faire des tests booléen (qui renvoient vrai ou faux).
# <ul>
#     <li> Égalité: <b>==</b> </li>
#     <li> Différence: <b>!=</b> </li>
#     <li> Supérieur: <b> > </b> </li>
#     <li> Supérieur ou égal: <b> >= </b> </li>
#     <li> Inférieur ou égal: <b> <= </b> </li>
#  </ul>
# <br />
# Il est aussi possible de combiner leur résultats avec <b>and</b> et <b>or</b> ou de les inverser avec <b>not</b>.
# </div>
#
# Demande à Python de vérifier si:

# %% [markdown]
# 3 + 3 est égal à 6

# %%
3 + 3 == 6
# Out:
# True

# %% [markdown]
# $7 \times 8$ est supérieur à 42

# %%
7 * 8 > 888
# Out:
# False

# %% [markdown]
# $304 \times 7.3$ est inférieur à 2222

# %%
304 * 7.3 < 2222
# Out:
# True

# %% [markdown]
# ## Arithmétique avancée
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
# Plusieurs <i>fonctions</i> sont aussi déjà implémentées pour des calculs plus avancés. Par exemple:
# <ul>
#     <li> Arrondi: <b>round( x )</b> </li>
#     <li> Minimum entre deux nombres: <b>min( x, y )</b> </li>
#     <li> Maximum entre deux nombres: <b>max( x, y )</b> </li>
#  </ul>
#
# Toutes ces opérations sont réalisées par des fonctions, reconnaissable car elles s'utilisent avec des parenthèses. On verra plus tard comment créer ses propres fonctions.
# </div>
#
# Demande à Python de calculer:

# %% [markdown]
# Le maximum entre 4 et 10

# %%
max(4, 10)
# Out:
# 10

# %% [markdown]
# Le minimum entre 0 et -4

# %%
min(0, -4)
# Out:
# -4

# %% [markdown]
# L'arrondi de $\dfrac{10}{3}$

# %%
round(10 / 3)
# Out:
# 3

# %% [markdown]
# # Les variables
# <style>
# div.info {
#     background-color: #FF8D3A;
#     color: white;
#     border-left: 5px solid #DE630A;
#     padding: 0.5em;
#     margin-left: 2em;
#
#     }
#  </style>
#
# <div class="info">
#
# Les variables sont un concept clé dans <b>tous</b> les langages de programmation.
#
# <b>Une variable</b> c'est une boite qui a une étiquette (un <b><i>nom</i></b>) et dans laquelle on peut stocker une <b><i>valeur</i></b> pour la lire ou la réutiliser plus tard.
#
# <br/>
# </div>

# %% [markdown]
# ## Créer et lire une variable
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
# Pour créer une variable il suffit d'écrire son nom suivi d'un <b>=</b> et de la valeur qu'on veut lui donner.
#
# Évidemment plusieurs variables peuvent exister dans un même programme. La liste des variables peut être affichées dans Jupyter.
# </div>

# %% [markdown]
# Définit la variable ```pi``` et initialise la avec la valeur $3.1415$. Assure toi qu'elle apparait dans la liste des variables.

# %%
pi = 3.1415

# %% [markdown]
# Demande à Python de calculer la valeur de $2*\pi$

# %%
2 * pi
# Out:
# 6.283

# %% [markdown]
# Demande à python de calculer la valeur de $\dfrac{pi}{4}$

# %%
pi / 4
# Out:
# 0.785375

# %% [markdown]
# Définis la variable ``age`` avec pour valeur 4.

# %%
age = 4

# %% [markdown]
# Définis la variable ``majeur`` qui stocke le résultat du test: ``age`` est supérieur ou égal à 18.

# %%
patate = age >= 18

# %% [markdown]
# ## Modifier une variable

# %% [markdown]
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# La valeur d'une variable peut être modifiée de la même manière qu'elle est créée. <i>nom</i> = <i>nouvelle valeur</i>.
#
# </div>

# %% [markdown]
# Modifie la variable age pour que sa valeur soit 40. Vérifie que sa valeur a bien changée dans la liste des variables

# %%
age = 40

# %% [markdown]
# Met-à-jour la variable ```majeur``` pour tenir compte de la nouvelle valeur de ```age```.

# %%
patate = age >= 18

# %% [markdown]
# Additionne 1 à la valeur de ``age`` et stocke sa nouvelle valeur. Observe le résultat dans la liste de variable.

# %%
age = age - 1

# %% [markdown]
# Execute la dernière ligne à nouveau. Que ce passe-t-il pour la variable ``age``?

# %% [markdown]
# ## Les types de variables
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Les variables ont un <b>type</b> qui définit le type de valeur qu'elles peuvent stocker. En python ce type est déterminé automatiquement, mais pas en Java!
#
# Les types standards sont:
#
# <ul>
#     <li> <b>int</b>: un nombre entier </li>
#     <li> <b>float</b>: un nombre à virgule </li>
#     <li> <b>bool</b>: un booléen (vrai ou faux) </li>
#     <li> <b>str</b>: une chaine de caractère (du texte) </li>
#  </ul>
#
# </div>
#
# <br />
#
# <div class="info">
#
# Les <b>chaines de caractères</b> permettent de manipuler du texte. Elles sont <b>toujours</b> délimitées par des guillemets (simples ou doubles), sinon Python interprète le texte comme le nom d'une variable ou d'une fonction!
#
# </div>

# %% [markdown]
# Définis une variable ``prenom`` contenant ton prénom et une variable ``nom`` contenant ton nom de famille.

# %%
Prénom = "edmond"
Nom = "Laforest"

# %% [markdown]
# Définis une variable ``nom_complet`` contenant la "somme" de ``prenom`` et ``nom``. Affiche la valeur de ``nom_complet``.

# %%
nom_complet = Prénom + Nom
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gabri\OneDrive\Documents\GitHub\EV3-DriverStation\education\initiation_programmation.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gabri/OneDrive/Documents/GitHub/EV3-DriverStation/education/initiation_programmation.ipynb#Y224sZmlsZQ%3D%3D?line=0'>1</a> nom_complet=Prénom+Nom
#
# NameError: name 'Prénom' is not defined

# %% [markdown]
# Définis la variable ``couleur`` avec pour valeur ``"rouge"``.

# %%
couleur = "rouge"

# %% [markdown]
# Définis la variable ma_couleur avec pour valeur ta couleur préférée.

# %%
ma_couleur = "mauve"

# %% [markdown]
# Demande à Python de vérifier si les variables ``couleur`` et ``ma_couleur`` ont la même valeur.

# %%
couleur == ma_couleur
# Out:
# False

# %% [markdown]
# # Les Fonctions
# <style>
# div.info {
#     background-color: #FF8D3A;
#     color: white;
#     border-left: 5px solid #DE630A;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Une fonction est un regroupement d'une série d'instructions qui réalisent une tache. Elle est définie par un nom (comme <i>min</i> ou <i>round</i>) et une série d'argument (comme <i>round(<b>x</b>)</i> ou <i>min(<b>a, b</b>)</i> ).
#
# </div>

# %% [markdown]
# ## Appeler une fonction
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Pour appeler une fonction il suffit d'écrire son nom suivi de parenthèses et des arguments qu'on veut lui donner. La fonction est alors executé et renvoie un résultat.
#
# </div>

# %% [markdown]
# La fonction ``print()`` permet d'afficher du texte ou des valeurs de variables. Appelle la fonction ``print`` avec comme argument ``"Bonjour!"``.

# %%
print("Bonjour")
# Out:
# Bonjour

# %% [markdown]
# La fonction ``print`` peut prendre plusieurs arguments. Appelle la fonction ``print`` avec comme arguments ``"Bonjour "`` et la variable ``prenom``.

# %%
print("Bonjour", Prénom)
# Out:
# Bonjour edmond

# %% [markdown]
# La fonction ``type()`` permet de lire le type d'une variable.
#
# Affiche le type de la variable ``age``.

# %%
type(age)
# Out:
# int

# %% [markdown]
# Affiche le type de la variable ``prenom``.

# %%
type(Prénom)
# Out:
# str

# %% [markdown]
# Affiche le type de la variable ``majeur``.

# %%
type(patate)
# Out:
# bool

# %% [markdown]
# La fonction ``sorted()`` tri par ordre alphabétique les caractères d'une mot.
#
# Tri les lettres de ton prénom par ordre alphabétique avec cette fonction.

# %%
sorted(Prénom)
# Out:
# ['d', 'd', 'e', 'm', 'n', 'o']

# %% [markdown]
# ## Créer une fonction
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Pour définir une nouvelle fonction, on utilise la syntaxe suivante:
#
# </div>
#
# ```python
# def nom_de_la_fonction( argument1, argument2, ... ):
#     ...
#     return resultat
# ```

# %% [markdown]
# Code la fonction ``deg2rad(angle)`` qui convertie un angle en degrés selon la formule: $\text{angle} \times \dfrac{\pi}{180}$

# %%
def deg2rad(angle):
    return angle * pi / 180
# Out:
# 6.283185307179586

# %% [markdown]
# Code la fonction ``perimètre(rayon)`` qui calcule le périmètre d'un cercle avec la formule: $\text{rayon} \times 2\pi$

# %%
def perimètre(rayon):
    return rayon * 2 * pi


perimètre(40)
# Out:
# 251.32741228718345

# %% [markdown]
# # Les Conditions
# <style>
# div.intro {
#     background-color: #FF8D3A;
#     color: white;
#     border-left: 5px solid #DE630A;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="intro">
#
# Les conditions permettent de changer la série d'instruction à exécuter en fonction du résultat d'une expression booléenne.
#
# </div>
#
#
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info"
#
# En python les conditions sont notés avec la syntaxe:
#
# <b>if</b> <i>condition</i>:
#
# <i style="margin-left: 4em">instruction à executer</i>
#
# <b>else</b>:
#
# <i style="margin-left: 4em">autres instructions à executer</i>
#
# </div>

# %% [markdown]
# En réutilisant la variable ``age``, vérifie que la personne est majeure. Si c'est le cas affiche ``"Tu es majeur"`` sinon affiche ``"Tu es mineur"``.

# %%
if age >= 18:
    print("Tu es majeur")
else:
    print("Tu es mineur")
# Out:
# Tu es mineur

# %% [markdown]
# Code la fonction ``min(a, b)`` qui renvoie le minimum entre ``a`` et ``b``.
#
# N'utilise **pas** la fonction de python, mais des conditions!

# %%
def minedo(a, b):
    if a < b:
        return a
    else:
        return b


minedo(30, 40)
# Out:
# 30

# %% [markdown]
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Le mot clé <b>elif</b> permet de tester une autre condition si la première est fausse.
#
# </div>

# %% [markdown]
# Écris une fonction ``stade_de_croissance(age)`` qui prend un age en argument et qui affiche "Tu n'es pas né" si l'age est inférieur à 0, "Tu es un bébé" si l'age est entre 0 et 2, "Tu es un enfant" si l'age est entre 2 et 12, "Tu es un adolescent" si l'age est entre 12 et 18, "Tu es un adulte" si l'age est entre 18 et 120, "Tu es un dinosaure" si l'age est supérieur à 120.
#
# Teste cette fonction avec plusieurs valeurs d'age.

# %%
def sdc(age):
    if age < 0:
        print("Tu n'es pas né")
    elif age <= 2:
        print("Tu es un bébé")
    elif age <= 12:
        print("Tu es un enfant")
    elif age <= 18:
        print("Tu es un ado")
    elif age <= 120:
        print("Tu es un adulte")
    elif age > 120:
        print("Tu es un dinosaure")

# %% [markdown]
# # Les boucles
# <style>
# div.info {
#     background-color: #FF8D3A;
#     color: white;
#     border-left: 5px solid #DE630A;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Les boucles permettent de répéter une série d'instruction un certain nombre de fois ou jusqu'à ce qu'une condition soit remplie.
#
# </div>

# %% [markdown]
# <style>
# div.info {
#     background-color: #62c0ed;
#     color: white; //#176BC7;
#     border-left: 5px solid #1a81b2;
#     padding: 0.5em;
#     display: inline-block
#     }
#  </style>
#
# <div class="info">
#
# Il existe deux types de boucles en Python (et dans la majorité des langages de programmations):
#
# <b>Les boucles for</b> permettent de répéter une série d'instruction n fois. Elle s'utilise avec <b>for i in range(n):</b>.
#
# <b>Les boucles while</b> permettent de répéter une série d'instruction tant qu'une condition est valide. Elle s'utilise avec <b>while condition:</b>.
#
# </div>

# %% [markdown]
# Execute le code suivant. Que fait ce code? Dans quel ordre sont executés les lignes de code?

# %%
for age in range(25):
    majeur = age >= 18
    if age == 0:
        print("Aujourd'hui tu es né!")
    elif majeur:
        print("Aujourd'hui tu as ", age, "ans. Tu es majeur.")
    else:
        print("Aujourd'hui tu as ", age, "ans. Tu n'es pas majeur.")
# Out:
# Aujourd'hui tu es né!
# Aujourd'hui tu as  1 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  2 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  3 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  4 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  5 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  6 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  7 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  8 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  9 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  10 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  11 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  12 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  13 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  14 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  15 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  16 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  17 ans. Tu n'es pas majeur.
# Aujourd'hui tu as  18 ans. Tu es majeur.
# Aujourd'hui tu as  19 ans. Tu es majeur.
# Aujourd'hui tu as  20 ans. Tu es majeur.
# Aujourd'hui tu as  21 ans. Tu es majeur.
# Aujourd'hui tu as  22 ans. Tu es majeur.
# Aujourd'hui tu as  23 ans. Tu es majeur.
# Aujourd'hui tu as  24 ans. Tu es majeur.

# %% [markdown]
# Calcul $2^3$ et $2^4$ avec des multiplications.

# %%
2 * 2 * 2 * 2
# Out:
# 16

# %% [markdown]
# Code la fonction ``puissance(x, n)`` qui renvoie $x^{n}$

# %%
def puissance(x, n):
    resultat = 1
    for i in range(n):
        resultat = x * resultat
    return resultat


puissance(3, 3)
# Out:
# 27
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
resultat = 2 * resultat

# %% [markdown]
# Code la fonction somme(n) qui calcule la some: $1 + 2 + 3 + ... + n$. Quelle est la valeur de $1 + 2 + 3 + ... + 99 + 100$?

# %% [markdown]
# **Bonus** : Code la fonction ``approximate_pi()`` qui approxime $\pi$ avec la formule:
# $\pi = 2 \times \Big( \dfrac{1\times2}{1\times3} + \dfrac{1\times2\times3}{1\times3\times5} + \dfrac{1\times2\times3\times4}
# {1\times3\times5\times7} + ... \Big)$
#
# Utilise une boucle et 100 itération pour approximer $\pi$.
