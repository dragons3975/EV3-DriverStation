# %%
import EV3DriverStation as ev3
robot = ev3.RobotAPI("192.168.0.183")

# %%
robot.avance(1)

# %%
robot.avance(2, 1)
robot.tourne_droite(1, .7)

# %%
for i in range(10):
    robot.avance(2, 1)
    robot.tourne_droite(1, .7)
