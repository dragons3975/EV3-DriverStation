# %% [markdown]
# <p style="text-align: center; font-size: 35px;">Controller le Robot avec Python</p>

# %% [markdown]
# Nous allons faire bouger un robot EV3 avec Python. Le code dans la cellule ci-dessous permet de se connecter au robot.
#
# Après avoir exécuté la cellule, la variable `robot` contient un objet avec 4 fonctions:
# - `robot.avance(temps, puissance)` : le robot avance pendant `temps` secondes avec une puissance de `puissance` (entre 0 et 1).
# - `robot.recule(temps, puissance)` : le robot recule pendant `temps` secondes avec une puissance de `puissance` (entre 0 et 1).
# - `robot.tourne_gauche(temps, puissance)` : le robot tourne à gauche pendant `temps` secondes avec une puissance de `puissance` (entre 0 et 1).
# - `robot.tourne_droite(temps, puissance)` : le robot tourne à droite pendant `temps` secondes avec une puissance de `puissance` (entre 0 et 1).
#
# - `robot.positionMoteur1` : la position du moteur 1 (en degrés)
# - `robot.positionMoteur2` : la position du moteur 2 (en degrés)
# - `robot.capteurCouleur` : le code de la couleur détectée par le capteur de couleur
# - `robot.capteurTactile` : True si le capteur tactile est appuyé, False sinon
#
# Tu va coder des petits "mode autonome" avec ces instructions.

# %%
from simple_ev3_api import RobotAPI

robot = RobotAPI("192.168.0.172")

# %% [markdown]
# Fait avancer le robot de 1 mètre en ligne droite

# %% [markdown]
# Fait avancer le robot de 1 mètre en ligne droite puis fais le reculer de 1 mètre

# %% [markdown]
# Fait faire un tour au robot sur lui même.

# %% [markdown]
# Combien de temps faut-il au robot pour faire un virage de 90 degrés?

# %% [markdown]
# ## Calibration des moteurs
# Affiche la position actuelle des moteurs.

# %% [markdown]
# Créer une fonction `moyenneMoteur()` qui somme la position du moteur1 et le moteur 2 et qui divise par 2.
#
# Cette fonction retourne la position moyenne des moteurs. Affiche et stocke sa valeur.

# %% [markdown]
# Avance pendant 3 seconde à 50% de la puissance maximale, affiche la nouvelle position moyenne des moteurs.

# %% [markdown]
# Calcule la différence entre les positions initiales et finales des moteurs.
